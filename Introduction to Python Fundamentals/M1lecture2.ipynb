# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
message = "Hello, world!"
print(message)
# Out:
# Hello, world!

# %%
print("message")
# Out:
# message

# %%
type(message)
# Out:
# str

# %%
type("Hello, world!")
# Out:
# str

# %%
type(input('Enter something:'))
# Out:
# Enter something:129
# str
